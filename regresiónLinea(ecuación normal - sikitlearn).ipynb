# %% [markdown]
# # tarea 1

# %% [markdown]
# Basado en https://es.wikipedia.org/wiki/Regresi%C3%B3n_lineal

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Caso de uso: regresión lineal.
#
# Según lo descrito en el wikipage sobre la regresión lineal y utilizando las fórmulas anteriores.
#
# Obtener mediante Numpy los valores de las constantes $B_1$ y $B_0$ de tal manera que ajuste mejor a la línea recta para los siguientes datos

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ¿Qué índice de mortalidad se podría predecir para una población que consume una media  de 32 cigarrillos diarios?

# %% [markdown]
# Representación gráfica de los datos

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.array([3,5,6,15,20,40,45])
y = np.array([0.2,0.3,0.3,0.5,0.7,1.4,1.5])

#Se grafica para ver los datos de forma gráfica
plt.plot(x, y, 'o')
m, b = np.polyfit(x, y, 1)
plt.plot(x, m*x + b)

# %% [markdown]
# Ecuación normal

# %%
#se determinar los valores con las ecuaciones normales
m = (np.sum(x) * np.sum(y)- len(x) * np.sum(x*y)) / \
(np.sum(x) ** 2- len(x)*np.sum(x**2))

b = (np.sum(y) - m *np.sum(x)) / len(x)

# %% [markdown]
# Predicción

# %%
#Se realiza la predicción
predictX=32
predictY=(m*predict) + b
predictY
# Out:
# 1.103695864539238

# %% [markdown]
# Validación de la Predicción

# %%
#Se grafica el valor de la predicción
plt.scatter(x, y)
plt.scatter(predictX, predictY)
plt.plot(x, y, 'o')
m, b = np.polyfit(x, y, 1)
plt.plot(x, m*x + b)
plt.show()

# %% [markdown]
# Segunda parte

# %% [markdown]
# Validar la solución anterior utilizando el regresor lineal en Python, utilizando la librería sklearn que se describe en el wikipage adjunto

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

X = x[:, np.newaxis]
model.fit(X, y)
Y=model.predict( np.array([predictX]).reshape(-1, 1))

# %% [markdown]
# Comparación entre la ecuación normal y sklearn

# %%
#Se grafica el valor de la predicción
plt.scatter(x, y)
plt.scatter(predictX, predictY)
plt.scatter(predictX, Y[0])
plt.plot(x, y, 'o')
m, b = np.polyfit(x, y, 1)
plt.plot(x, m*x + b)
plt.show()
